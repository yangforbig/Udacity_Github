# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# set plot color for dark theme
from jupyterthemes import jtplot
jtplot.style()

# %%
train = pd.read_csv('train.csv', header = 0, dtype={'Age': np.float64})
test  = pd.read_csv('test.csv' , header = 0, dtype={'Age': np.float64})
dataList = [train, test]

# %% [markdown]
# ## 1. Feature Engineering and Data Processing

# %%
exploreFeatures = ['Survived', 'Pclass', 'Sex', 'Age',
                   'Fare', 'Embarked', 'FamilySize', 
                   'isAlone', 'Title']

# %%
categoricalFeatuers = ['Survived', 'Pclass', 'Sex', 'Embarked','isAlone', 'Title']
numericalFeatuers = ['Age', 'Fare' , 'FamilySize']

# %% [markdown]
# First we create a new feature Titles from feature Name, which means we get the title out of each name.

# %%
# Get the Title from the Name
import re

def get_title(name):
	title_search = re.search(' ([A-Za-z]+)\.', name)
	# If the title exists, extract and return it.
	if title_search:
		return title_search.group(1)
	return ""

for dataset in dataList:
    dataset['Title'] = dataset['Name'].apply(get_title)

# %%
# format the title
for dataset in dataList:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
print(pd.crosstab(train['Title'], train['Sex']))
titles = train.Title.unique()
# Out:
# Sex     female  male
# Title
# Master       0    40
# Miss       185     0
# Mr           0   517
# Mrs        126     0
# Rare         3    20

# %% [markdown]
# Check missing values for each feature.

# %%
# Missing Value Detection
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %% [markdown]
# Feature Cabin has the most occurences of NA value. Since cabin is just the serial numbers, it is not necessary to impute. We have lots of missing valus in Age, so generate numbers from between (mean - std) and (mean + std) to impute. We only have two missing values in Embarked, median imputation will be applied. For the clarification, I check the characteristics age distribution first then decide this method to impute the age.

# %%
titles
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Rare'], dtype=object)

# %%
def impute_age(data, title):
    ageMean = data[data.Title == title].Age.mean()
    ageStd = data[data.Title == title].Age.std()
    nullIndex = data[data.Title == title].Age.isnull()
    size = nullIndex.sum()
    impute_data = np.random.randint(ageMean - ageStd, ageMean + ageStd, size=size)
    data.Age[data.Title == title][nullIndex] = impute_data
    #data['Age'] = data['Age'].astype(int)
    return data

# %%
testPd = train.copy()

# %%
for title in titles:
    impute_age(testPd, title)

# %% [markdown]
# ## Univariate Analysis

# %%
def uni_cate_plot(data, feature):
    fig, ax = plt.subplots()
    ax = sns.stripplot(x = data[feature].unique(), y = data[feature].value_counts()/len(data))
    plt.xlabel(feature)
    plt.ylabel('Rate')
    print data[feature].value_counts() / len(data)

# %%
uni_cate_plot(train, 'Survived')
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# Survive Rate is 38.3%, which means the dataset is pretty skewed.

# %%
uni_cate_plot(train, 'Pclass')
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %% [markdown]
# First class passengers of all: 24.2%
#
# Second class passengers: 20.7%
#
# Third class passengers: 55%

# %%
uni_cate_plot(train, 'Sex')
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %% [markdown]
# Male passengers: 64.8%
#
# Female passengers: 35.2%

# %%
uni_cate_plot(train, 'Embarked')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-de2307839bd8> in <module>()
# ----> 1 uni_cate_plot(train, 'Embarked')
#
# <ipython-input-6-64cbd2a6e5c7> in uni_cate_plot(data, feature)
#       1 def uni_cate_plot(data, feature):
#       2     fig, ax = plt.subplots()
# ----> 3     ax = sns.stripplot(x = data[feature].unique(), y = data[feature].value_counts()/len(data))
#       4     plt.xlabel(feature)
#       5     plt.ylabel('Rate')
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in stripplot(x, y, hue, data, order, hue_order, jitter, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2545
#    2546     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
# -> 2547                             jitter, split, orient, color, palette)
#    2548     if ax is None:
#    2549         ax = plt.gca()
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, jitter, split, orient, color, palette)
#    1110                  jitter, split, orient, color, palette):
#    1111         """Initialize the plotter."""
# -> 1112         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1113         self.establish_colors(color, palette, 1)
#    1114
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     201                 # Group the numeric data
#     202                 plot_data, value_label = self._group_longform(vals, groups,
# --> 203                                                               group_names)
#     204
#     205                 # Now handle the hue levels for nested ordering
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in _group_longform(self, vals, grouper, order)
#     243
#     244         # Group the val data
# --> 245         grouped_vals = vals.groupby(grouper)
#     246         out_data = []
#     247         for g in order:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3991                        **kwargs)
#    3992
#    3993     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1509         raise TypeError('invalid type: %s' % type(obj))
#    1510
# -> 1511     return klass(obj, by, **kwds)
#    1512
#    1513
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     368                                                     level=level,
#     369                                                     sort=sort,
# --> 370                                                     mutated=self.mutated)
#     371
#     372         self.obj = obj
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort, mutated)
#    2482                         sort=sort,
#    2483                         in_axis=in_axis) \
# -> 2484             if not isinstance(gpr, Grouping) else gpr
#    2485
#    2486         groupings.append(ping)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, index, grouper, obj, name, level, sort, in_axis)
#    2187         self.name = name
#    2188         self.level = level
# -> 2189         self.grouper = _convert_grouper(index, grouper)
#    2190         self.index = index
#    2191         self.sort = sort
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _convert_grouper(axis, grouper)
#    2510     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#    2511         if len(grouper) != len(axis):
# -> 2512             raise AssertionError('Grouper and axis must be same length')
#    2513         return grouper
#    2514     else:
#
# AssertionError: Grouper and axis must be same length

# %% [markdown]
# C = Cherbourg, Q = Queenstown, S = Southampton
#
# Embarkation Port for Sourthhampton, Queenstown, Cherbourg: 72.5%, 18.9%, 8.6%

# %%
uni_cate_plot(train, 'isAlone')
# Out:
# 1    0.602694
# 0    0.397306
# Name: isAlone, dtype: float64

# %% [markdown]
# 40% of passengers are alone on this trip

# %%
uni_cate_plot(train, 'Title')
# Out:
# Mr        0.580247
# Miss      0.207632
# Mrs       0.141414
# Master    0.044893
# Rare      0.025814
# Name: Title, dtype: float64

# %%
# Kenel Density Estimation 

for title in titles:   
    ax = sns.distplot(train[train.Title == title].Age.dropna(), hist=False, label = title)
plt.legend()

# %%
ax = sns.distplot(train.Age.dropna(), color="g")
print train.Age.describe()
# Out:
# count    886.000000
# mean      29.535181
# std       13.520390
# min        0.420000
# 25%       21.000000
# 50%       28.000000
# 75%       37.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Some interesting findings from the plots above are :
#
# (1) Age distribution approximately follow a normal distritbion except for a bump on its left tail.
#
# (2) Mean and standard deviation for the age are 30 and 13.5. 75% passengers are younger 37.
#
# (3) members of Master group are mostly under 10 years old and accounts for 4.4% of the total travellers.

# %% [markdown]
# Fare distribution looks like following a Pareto distribution. 75% fare is less than $31

# %%
familysizeCount = pd.DataFrame({'Counts' : train.FamilySize.value_counts()})
familysizeCount['Ratio'] = familysizeCount / len(train)
familysizeCount
# Out:
#     Counts     Ratio
# 1      537  0.602694
# 2      161  0.180696
# 3      102  0.114478
# 4       29  0.032548
# 6       22  0.024691
# 5       15  0.016835
# 7       12  0.013468
# 11       7  0.007856
# 8        6  0.006734

# %% [markdown]
# ## Multivariate Analysis

# %%
categoricalFeatuers = ['Survived', 'Pclass', 'Sex', 'Embarked','isAlone', 'Title']
numericalFeatuers = ['Age', 'Fare' , 'FamilySize']

# %% [markdown]
# Since we are very interested in the variabes related to the Survival. The multivariate analysis and visulization will around the feature 'Survived'

# %%
def feature_weight(data, feature):
    return data[[feature, 'Survived']].groupby(feature, as_index=False).mean()

# %%
# Pclass
pclass_plot = feature_weight(train, 'Pclass')
pclass_plot.Pclass = pclass_plot.Pclass.astype(str)

#ax = sns.barplot(x = 'Survived', y= 'Pclass', data=pclass_plot)
print pclass_plot.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1106-c28535ce6544> in <module>()
#       3 pclass_plot.Pclass = pclass_plot.Pclass.astype(str)
#       4
# ----> 5 ax = sns.barplot(x = 'Survived', y= 'Pclass', data=pclass_plot)
#       6 print pclass_plot.dtypes
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
#    1543                                  order, hue_order, units)
#    1544         self.establish_colors(color, palette, saturation)
# -> 1545         self.estimate_statistic(estimator, ci, n_boot)
#    1546
#    1547         self.errcolor = errcolor
#
# /anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in estimate_statistic(self, estimator, ci, n_boot)
#    1438                     statistic.append(np.nan)
#    1439                 else:
# -> 1440                     statistic.append(estimator(stat_data))
#    1441
#    1442                 # Get a confidence interval for this estimate
#
# /anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2940
#    2941     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2942                             out=out, **kwargs)
#    2943
#    2944
#
# /anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      70         ret = ret.dtype.type(ret / rcount)
#      71     else:
# ---> 72         ret = ret / rcount
#      73
#      74     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
sns.stripplot(x="CategoricalFare", y="Survived", data=df)

# %%
# Plots with feature 'Pclass', 'Fare', and 'Survived'
plt.figure(figsize=(6, 6))
ax = sns.swarmplot(x="Pclass", y="Fare", data=train, hue="Survived")

# %% [markdown]
# First Class tickets holders obviously has more chance to survive, espically for those highest fare tickets holders in the first class.

# %%
# Sex
feature_weight(train, 'Sex')
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.pointplot(x="Sex", y="Survived", hue="Pclass", data=train);

# %% [markdown]
# Female survival rate much larger than male, especially for 1st and 2nd classes, more than 85%

# %%
# create Fanily size creature
for dataset in dataList:
    dataset['FamilySize'] = dataset.SibSp + dataset.Parch + 1

# %%
feature_weight(train, 'FamilySize')
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %%
plotFamilysize = feature_weight(train, 'FamilySize')
plotFamilysize['isAlone'] = False
plotFamilysize.loc[0, 'isAlone'] = True
plotFamilysize
# Out:
#    FamilySize  Survived isAlone
# 0           1  0.303538    True
# 1           2  0.552795   False
# 2           3  0.578431   False
# 3           4  0.724138   False
# 4           5  0.200000   False
# 5           6  0.136364   False
# 6           7  0.333333   False
# 7           8  0.000000   False
# 8          11  0.000000   False

# %%
sns.stripplot(x="FamilySize", y="Survived", data=plotFamilysize, hue='isAlone')

# %%
train.groupby(['FamilySize', 'Survived', 'Sex']).size().unstack('Survived').plot(kind = 'bar')

# %% [markdown]
# People were travelling by themselves are not likely(30%) to survive the titanic.

# %%
# create isAlone feature
for dataset in dataList:
    dataset['isAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'isAlone'] = 1

# %%
feature_weight(train, 'isAlone')
# Out:
#    isAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
# imputate NA with S (Most occurence)
train.Embarked.fillna('S', inplace=True)

# %%
em_plot = feature_weight(train, 'Embarked')
ax = sns.barplot(x="Survived", y="Embarked", data=em_plot)
plt.yticks(xrange(3),('Cherbourg', 'Queenstown', 'Southampton'))
print em_plot.dtypes
# Out:
# Embarked     object
# Survived    float64
# dtype: object

# %% [markdown]
# Embarked at Cherbourg has higher survival rate 55.3%

# %%
feature_weight(train, 'Title')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c244cbcbfc44> in <module>()
# ----> 1 feature_weight(train, 'Title')
#
# NameError: name 'feature_weight' is not defined

# %% [raw]
# pd.crosstab(train.Title, train.Sex)

# %%
train['CategoricalAge'] = pd.qcut(train['Age'], 4)

# %%
titles = train.Title.unique()

# %%
plt.figure(figsize=(15,15))
ax = sns.boxplot(x="Title", y="Age", hue="Title", data=train)
ax = sns.swarmplot(x="Title", y="Age", data=train, hue="Survived", color='0.6')

# %%
for title in titles:
    print title + ":\n" 
    print train[train.Title==title].Age.describe()
    print "\n"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-318d2fecdf41> in <module>()
# ----> 1 for title in titles:
#       2     print title + ":\n"
#       3     print train[train.Title==title].Age.describe()
#       4     print "\n"
#
# NameError: name 'titles' is not defined

# %%
# Missing Value imputation in Age
print "Train: "
for title in titles:
    print  title + ":", train[train.Title == title].Age.isnull().sum()
print
print "Test: "
for title in titles:
    print title + ":", test[test.Title == title].Age.isnull().sum()
# Out:
# Train:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-4903a59415bc> in <module>()
#       1 # Missing Value imputation in Age
#       2 print "Train: "
# ----> 3 for title in titles:
#       4     print  title + ":", train[train.Title == title].Age.isnull().sum()
#       5 print
#
# NameError: name 'titles' is not defined

# %%
# Missing Value imputation in Age
print "Train: "
for title in titles:
    print  title + ":", train[train.Title == title].Age.isnull().sum()
print
print "Test: "
for title in titles:
    print title + ":", test[test.Title == title].Age.isnull().sum()
# Out:
# Train:
# Mr: 0
# Mrs: 0
# Miss: 0
# Master: 4
# Rare: 1
#
# Test:
# Mr: 0
# Mrs: 0
# Miss: 0
# Master: 4
# Rare: 0

# %%
for title in titles:
    print title + ":\n" 
    print train[train.Title==title].Age.describe()
    print "\n"
# Out:
# Mr:
#
# count    517.000000
# mean      32.010638
# std       11.706992
# min       11.000000
# 25%       23.000000
# 50%       30.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
#
#
# Mrs:
#
# count    126.000000
# mean      35.158730
# std       10.924038
# min       14.000000
# 25%       27.000000
# 50%       34.000000
# 75%       42.750000
# max       63.000000
# Name: Age, dtype: float64
#
#
# Miss:
#
# count    185.000000
# mean      21.740541
# std       11.956993
# min        0.750000
# 25%       15.000000
# 50%       21.000000
# 75%       30.000000
# max       63.000000
# Name: Age, dtype: float64
#
#
# Master:
#
# count    36.000000
# mean      4.574167
# std       3.619872
# min       0.420000
# 25%       1.000000
# 50%       3.500000
# 75%       8.000000
# max      12.000000
# Name: Age, dtype: float64
#
#
# Rare:
#
# count    22.000000
# mean     45.545455
# std      11.782664
# min      23.000000
# 25%      38.500000
# 50%      48.500000
# 75%      53.500000
# max      70.000000
# Name: Age, dtype: float64

# %%
# impute 'Master','Rare' with Median
for dataset in dataList:
    for title in titles[3:]:
        median = dataset[dataset.Title == title].Age.median()
        fillData = dataset.loc[dataset.Title == title, 'Age'].fillna(median)
        dataset.loc[dataset.Title == title, 'Age'] = fillData

# %% [markdown]
# ## Data Cleaning

# %%
for dataset in dataList:
    # mapping Sex
    dataset['Sex'] = dataset['Sex'].map({'female': 0, 'male': 1})
    # mapping title
    titleMapping = { titles[e] : (e + 1) for e in range(len(titles)) }
    dataset['Title'] = dataset['Title'].map(titleMapping)
    # mapping Embarked
    #dataset['Embarked'] = dataset['Embarked'].map({'S': 0, 'C': 1, 'Q' : 2 })

# %%
train.Title.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-36136ecabf4f> in <module>()
# ----> 1 train.Title.head()
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Title'

# %%
titleMapping
# Out:
# {'Master': 4, 'Miss': 3, 'Mr': 1, 'Mrs': 2, 'Rare': 5}

# %%
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Sex, dtype: int64

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
# PassengerId        891 non-null int64
# Survived           891 non-null int64
# Pclass             891 non-null int64
# Name               891 non-null object
# Sex                891 non-null int64
# Age                891 non-null float64
# SibSp              891 non-null int64
# Parch              891 non-null int64
# Ticket             891 non-null object
# Fare               891 non-null float64
# Cabin              204 non-null object
# Embarked           891 non-null object
# FamilySize         891 non-null int64
# isAlone            891 non-null int64
# CategoricalFare    891 non-null category
# Title              891 non-null object
# dtypes: category(1), float64(2), int64(8), object(5)
# memory usage: 105.4+ KB

# %%
np.random.seed(10)

# Sample data randomly at fixed probabilities
voter_race = np.random.choice(a= ["asian","black","hispanic","other","white"],
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

# Sample data randomly at fixed probabilities
voter_party = np.random.choice(a= ["democrat","independent","republican"],
                              p = [0.4, 0.2, 0.4],
                              size=1000)

voters = pd.DataFrame({"race":voter_race, 
                       "party":voter_party})

voter_tab = pd.crosstab(voters.race, voters.party, margins=True)

voter_tab.columns = ["democrat","independent","republican","row_totals"]

voter_tab.index = ["asian","black","hispanic","other","white","col_totals"]

observed = voter_tab.ix[0:5,0:3]   # Get table without totals for later use
voter_tab
# Out:
#             democrat  independent  republican  row_totals
# asian             21            7          32          60
# black             65           25          64         154
# hispanic         107           50          94         251
# other             15            8          15          38
# white            189           96         212         497
# col_totals       397          186         417        1000
